# %%
# !git clone https://github.com/munir-fati-haji/Thesis-Multiple-Object-Tracking.git
# Out:
# Cloning into 'Thesis-Multiple-Object-Tracking'...
# remote: Enumerating objects: 54698, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 54698 (delta 5), reused 48 (delta 4), pack-reused 54649
# Receiving objects: 100% (54698/54698), 52.61 MiB | 25.70 MiB/s, done.
# Resolving deltas: 100% (2723/2723), done.
# Updating files: 100% (56354/56354), done.

# %%
nanoPath = "Thesis-Multiple-Object-Tracking/results/Summary/Training/nano.csv"
smallPath = "Thesis-Multiple-Object-Tracking/results/Summary/Training/small.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Load the data from the CSV files
datasets = {
    "nano": pd.read_csv(nanoPath),
    "small": pd.read_csv(smallPath)
}

# Define the loss categories and subplot titles
loss_categories = {
    "train/box_loss": "Training Box Loss",
    "val/box_loss": "Validation Box Loss",
    "train/cls_loss": "Training Class Loss",
    "val/cls_loss": "Validation Class Loss",
    "train/dfl_loss": "Training DFL Loss",
    "val/dfl_loss": "Validation DFL Loss"
}

# Create a figure with subplots
fig = plt.figure(figsize=(7, 7))
gs = gridspec.GridSpec(3, 2, figure=fig)

# Iterate over the loss categories and subplot positions
for idx, (loss_key, loss_title) in enumerate(loss_categories.items()):
    i, j = divmod(idx, 2)  # Calculate the subplot indices

    axs = fig.add_subplot(gs[i, j])
    for dataset_key, dataset in datasets.items():
        # Plot the data for each dataset on a separate subplot
        axs.plot(dataset[loss_key], label=dataset_key)
    axs.set_ylabel(loss_title)
    axs.set_title(f"{loss_title} vs Epoch")
    axs.set_xlabel("Epoch")
    axs.legend()

    # Format y-axis to display one decimal place
    axs.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f"{x:.2f}"))
    
    # Show max number on x-axis
    max_x = max(dataset.index) + 1
    axs.set_xticks([0, max_x])
# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.7, wspace=0.5)

# Save Plot
plt.savefig("loss.png")

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Load the data from the CSV files
datasets = {
    "nano": pd.read_csv(nanoPath),
    "small": pd.read_csv(smallPath)
}

# Define the loss categories and subplot titles
loss_categories = {
    "metrics/precision(B)": "Precision",
    "metrics/recall(B)": "Recall",
    "metrics/mAP50(B)": "mAP50",
    "metrics/mAP50-95(B)": "mAP50-95"
}

# Create a figure with subplots
fig = plt.figure(figsize=(6, 5))
gs = gridspec.GridSpec(2, 2, figure=fig)

# Iterate over the loss categories and subplot positions
for idx, (loss_key, loss_title) in enumerate(loss_categories.items()):
    i, j = divmod(idx, 2)  # Calculate the subplot indices

    axs = fig.add_subplot(gs[i, j])
    for dataset_key, dataset in datasets.items():
        # Plot the data for each dataset on a separate subplot
        axs.plot(dataset[loss_key], label=dataset_key)
    axs.set_ylabel(loss_title)
    axs.set_title(f"{loss_title} vs Epoch")
    axs.set_xlabel("Epoch")
    axs.legend()

    # Format y-axis to display one decimal place
    axs.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f"{x:.2f}"))
    
    # Show max number on x-axis
    max_x = max(dataset.index) + 1
    axs.set_xticks([0, max_x])
# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.7, wspace=0.5)

# Save Plot
plt.savefig("metrics.png")

# Display the plot
plt.show()

# %%
nano = pd.read_csv("nano.csv")
nano.columns
# Out:
# Index(['epoch', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')
